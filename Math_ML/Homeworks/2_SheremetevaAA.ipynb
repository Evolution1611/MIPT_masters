# %% [markdown]
# # Условия

# %%
from numpy import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

random_array = random.normal(size=1000)
sns.distplot(random_array, hist=False)

plt.show()
# Out:
# c:\Users\shere\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
series = pd.Series(random_array)

# %% [markdown]
# Перед вами нормально-распределенный массив сконвертированный в Pandas Series. Необходимо расчитать следующие статистики для массива (series), используя только собственно-написанные формулы:
# * среднее значение
# * медиану
# * стандартное отклонение
# * межквартильный размах
# * 23-й перцентиль

# %%
series
# Out:
# 0     -0.771619
# 1     -0.462712
# 2      1.062536
# 3     -1.045712
# 4      0.324283
#          ...
# 995    1.155553
# 996    0.596594
# 997    0.037387
# 998    0.617728
# 999   -2.454997
# Length: 1000, dtype: float64

# %% [markdown]
# # *Домашнее задание:*

# %% [markdown]
# **Задача 1**
# Среднее значение

# %%
# используя только собственно-написанные формулы
lst = series
count = len(lst)
def my_mean(x):
    sum_lst = 0
    for i in lst:
        sum_lst +=i
    res = (sum_lst)/count
    return res 
a = my_mean(lst)
print(a)  

# 0.01953758931496111
# Out:
# -0.01953758931496111

# %%
# Используя библиотеки
import numpy as np
b = np.mean(series)
print (b)

# Check
a == b

#-0.01953758931496111
#True
# Out:
# -0.01953758931496111
# True

# %%
# Out:
# True

# %% [markdown]
# **Задача 2**
# Медиана

# %%
# используя только собственно-написанные формулы
lst = sorted(series)
count = len(lst)
place = int(count/2)
def my_median(x):
    if count // 2 == 0:
        return (lst[place])
    else: 
        return ((lst[place]+lst[place-1])/2)
c = my_median(lst)
print(c)
# Out:
# -0.02662933819595112

# %%
# Используя библиотеки
d = np.median(series)
print (d)
# Out:
# -0.02662933819595112

# %%
# Check
c == d
# Out:
# True

# %% [markdown]
# **Задача 3**
# стандартное отклонение

# %%
sum_of_sq = 0
for i in series:
    sum_of_sq += (i - a)**2 #a - это среднее значение, найденное в 1 задаче
    sum_of_sq = sum(sum_of_sq)
    my_st_dev = (sum_of_sq)**0.5
    print (my_st_dev)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shere\OneDrive\Рабочий стол\MFTI\Math\Week 2\asset-v1_SkillFactory+MIPTDS+SEPT22+type@asset+block@2_ilyukhinan.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/shere/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/MFTI/Math/Week%202/asset-v1_SkillFactory%2BMIPTDS%2BSEPT22%2Btype%40asset%2Bblock%402_ilyukhinan.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> for i in series:
#       <a href='vscode-notebook-cell:/c%3A/Users/shere/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/MFTI/Math/Week%202/asset-v1_SkillFactory%2BMIPTDS%2BSEPT22%2Btype%40asset%2Bblock%402_ilyukhinan.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a>     sum_of_sq += (i - a)**2 #a - это среднее значение, найденное в 1 задаче
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shere/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/MFTI/Math/Week%202/asset-v1_SkillFactory%2BMIPTDS%2BSEPT22%2Btype%40asset%2Bblock%402_ilyukhinan.ipynb#X56sZmlsZQ%3D%3D?line=3'>4</a>     sum_of_sq = sum(sum_of_sq)
#       <a href='vscode-notebook-cell:/c%3A/Users/shere/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/MFTI/Math/Week%202/asset-v1_SkillFactory%2BMIPTDS%2BSEPT22%2Btype%40asset%2Bblock%402_ilyukhinan.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a>     my_st_dev = (sum_of_sq)**0.5
#       <a href='vscode-notebook-cell:/c%3A/Users/shere/OneDrive/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B8%D0%B9%20%D1%81%D1%82%D0%BE%D0%BB/MFTI/Math/Week%202/asset-v1_SkillFactory%2BMIPTDS%2BSEPT22%2Btype%40asset%2Bblock%402_ilyukhinan.ipynb#X56sZmlsZQ%3D%3D?line=5'>6</a>     print (my_st_dev)
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# **Задача 4**
# Межквартильный размах

# %% [markdown]
# **Задача 5**
# 23-й перцентиль
